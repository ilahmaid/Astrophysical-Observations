# %%
import numpy as np
from astropy.table import Table 
from matplotlib import pyplot as plt

# %%
dataT = Table.read('Measurements.txt', format='ascii')
dataT
# Out:
# <Table length=448>
#      col1        col2     col3
#    float64     float64  float64
# -------------- -------- --------
# 2459632.521654 0.299067 0.000937
# 2459632.522975 0.296918 0.000936
# 2459632.524293 0.294128 0.000923
#  2459632.52561 0.295252  0.00092
# 2459632.526928 0.294791 0.000937
# 2459632.528241 0.292793 0.000938
# 2459632.529555 0.297194 0.000926
# 2459632.530872 0.296725 0.000925
# 2459632.532222 0.296813 0.000944
# 2459632.533575 0.301668 0.000941
#            ...      ...      ...
#  2459646.69427 0.142992 0.000635
# 2459646.695809 0.143339 0.000629
#  2459646.69735  0.14467 0.000638
# 2459646.698885 0.145691 0.000647
# 2459646.700418  0.14415  0.00065
# 2459646.701972 0.143387 0.000664
# 2459646.703509 0.142864 0.000669
# 2459646.705045 0.141131 0.000666
# 2459646.706582 0.138695 0.000661
# 2459646.708117 0.139546 0.000669

# %%
f = open('Measurements.txt', 'r')
a = f.readlines()
a
# Out:
# ['2459632.521654\t0.299067\t0.000937\n',
#  '2459632.522975\t0.296918\t0.000936\n',
#  '2459632.524293\t0.294128\t0.000923\n',
#  '2459632.52561\t0.295252\t0.00092\n',
#  '2459632.526928\t0.294791\t0.000937\n',
#  '2459632.528241\t0.292793\t0.000938\n',
#  '2459632.529555\t0.297194\t0.000926\n',
#  '2459632.530872\t0.296725\t0.000925\n',
#  '2459632.532222\t0.296813\t0.000944\n',
#  '2459632.533575\t0.301668\t0.000941\n',
#  '2459632.534898\t0.300459\t0.000944\n',
#  '2459632.536232\t0.301328\t0.000937\n',
#  '2459632.537546\t0.300938\t0.000942\n',
#  '2459632.53886\t0.30018\t\t0.000947\n',
#  '2459632.540178\t0.300167\t0.000956\n',
#  '2459632.541508\t0.3015\t\t0.00096\n',
#  '2459632.542829\t0.29911\t\t0.000966\n',
#  '2459632.544156\t0.300032\t0.00096\n',
#  '2459632.545501\t0.301747\t0.000956\n',
#  '2459632.546829\t0.299917\t0.000955\n',
#  '2459632.548184\t0.300297\t0.000976\n',
#  '2459632.549542\t0.301315\t0.001121\n',
#  '2459632.550878\t0.297805\t0.001403\n',
# ...

# %%
b=[]
b_floats=[]
for i in range(0,447):
    b.append(a[i].split())
    b_trans = [float(bb) for bb in b[i]]
    b_floats.append(b_trans)
b_floats=np.array(b_floats)
b_floats
# Out:
# array([[2.45963252e+06, 2.99067000e-01, 9.37000000e-04],
#        [2.45963252e+06, 2.96918000e-01, 9.36000000e-04],
#        [2.45963252e+06, 2.94128000e-01, 9.23000000e-04],
#        ...,
#        [2.45964670e+06, 1.42864000e-01, 6.69000000e-04],
#        [2.45964671e+06, 1.41131000e-01, 6.66000000e-04],
#        [2.45964671e+06, 1.38695000e-01, 6.61000000e-04]])

# %% [markdown]
# **__À faire:__**
#
# 1) Fonction pour différencier les jours.
#
# 2) Définir à quel moment de la double-phase commence la journée.
#
# 3) Mettre en graphe les différentes courbes en superposition.
#
# 4) Extraire la courbe de lumière du mutual event.
